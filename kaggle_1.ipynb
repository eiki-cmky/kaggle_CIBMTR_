# %%
#csvファイルの読み込み
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df_train = pd.read_csv(r"C:\Users\eikik\python\python_dat\equity-post-HCT-survival-predictions\train.csv")

# %%
#データの確認
df_train.head()
# Out:
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No           NaN       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No           NaN       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6  ...          tce_div_match donor_related  \
# 0            6.0  ...                    NaN     Unrelated
# 1            6.0  ...  Permissive mismatched       Related
# 2            6.0  ...  Permissive mismatched       Related
# 3            6.0  ...  Permissive mismatched     Unrelated
# 4            6.0  ...  Permissive mismatched       Related
#
#        melphalan_dose hla_low_res_8 cardiac  hla_match_drb1_high  \
# 0  N/A, Mel not given           8.0      No                  2.0
# 1  N/A, Mel not given           8.0      No                  2.0
# 2  N/A, Mel not given           8.0      No                  2.0
# 3  N/A, Mel not given           8.0      No                  2.0
# 4                 MEL           8.0      No                  2.0
#
#   pulm_moderate  hla_low_res_10  efs efs_time
# 0            No            10.0  0.0   42.356
# 1           Yes            10.0  1.0    4.672
# 2            No            10.0  0.0   19.793
# 3            No            10.0  0.0  102.349
# 4            No            10.0  0.0   16.223
#
# [5 rows x 60 columns]

# %%
#データの次元の確認
df_train.shape
# Out:
# (28800, 60)

# %%
#データの情報
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28800 entries, 0 to 28799
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      28800 non-null  int64
#  1   dri_score               28646 non-null  object
#  2   psych_disturb           26738 non-null  object
#  3   cyto_score              20732 non-null  object
#  4   diabetes                26681 non-null  object
#  5   hla_match_c_high        24180 non-null  float64
#  6   hla_high_res_8          22971 non-null  float64
#  7   tbi_status              28800 non-null  object
#  8   arrhythmia              26598 non-null  object
#  9   hla_low_res_6           25530 non-null  float64
#  10  graft_type              28800 non-null  object
#  11  vent_hist               28541 non-null  object
#  12  renal_issue             26885 non-null  object
#  13  pulm_severe             26665 non-null  object
#  14  prim_disease_hct        28800 non-null  object
#  15  hla_high_res_6          23516 non-null  float64
#  16  cmv_status              28166 non-null  object
#  17  hla_high_res_10         21637 non-null  float64
#  18  hla_match_dqb1_high     23601 non-null  float64
#  19  tce_imm_match           17667 non-null  object
#  20  hla_nmdp_6              24603 non-null  float64
#  21  hla_match_c_low         26000 non-null  float64
#  22  rituximab               26652 non-null  object
#  23  hla_match_drb1_low      26157 non-null  float64
#  24  hla_match_dqb1_low      24606 non-null  float64
#  25  prod_type               28800 non-null  object
#  26  cyto_score_detail       16877 non-null  object
#  27  conditioning_intensity  24011 non-null  object
#  28  ethnicity               28213 non-null  object
#  29  year_hct                28800 non-null  int64
#  30  obesity                 27040 non-null  object
#  31  mrd_hct                 12203 non-null  object
#  32  in_vivo_tcd             28575 non-null  object
#  33  tce_match               9804 non-null   object
#  34  hla_match_a_high        24499 non-null  float64
#  35  hepatic_severe          26929 non-null  object
#  36  donor_age               26992 non-null  float64
#  37  prior_tumor             27122 non-null  object
#  38  hla_match_b_low         26235 non-null  float64
#  39  peptic_ulcer            26381 non-null  object
#  40  age_at_hct              28800 non-null  float64
#  41  hla_match_a_low         26410 non-null  float64
#  42  gvhd_proph              28575 non-null  object
#  43  rheum_issue             26617 non-null  object
#  44  sex_match               28539 non-null  object
#  45  hla_match_b_high        24712 non-null  float64
#  46  race_group              28800 non-null  object
#  47  comorbidity_score       28323 non-null  float64
#  48  karnofsky_score         27930 non-null  float64
#  49  hepatic_mild            26883 non-null  object
#  50  tce_div_match           17404 non-null  object
#  51  donor_related           28642 non-null  object
#  52  melphalan_dose          27395 non-null  object
#  53  hla_low_res_8           25147 non-null  float64
#  54  cardiac                 26258 non-null  object
#  55  hla_match_drb1_high     25448 non-null  float64
#  56  pulm_moderate           26753 non-null  object
#  57  hla_low_res_10          23736 non-null  float64
#  58  efs                     28800 non-null  float64
#  59  efs_time                28800 non-null  float64
# dtypes: float64(23), int64(2), object(35)
# memory usage: 13.2+ MB

# %%
#dri_scoreのデータ欠損割合を表示
df_train["dri_score"].isnull().sum()/df_train.shape[0]
# Out:
# 0.005347222222222222

# %%
#欠損値割合が小さいので、driver_scoreの欠損値を試しに最頻値で埋めてみる

# 最頻値を計算
dri_score_mode = df_train['dri_score'].mode()[0]

# 欠損値を最頻値で補完
df_train['dri_score'] = df_train['dri_score'].fillna(dri_score_mode)

# 補完後の欠損値の確認
missing_after = df_train['dri_score'].isnull().sum()
print(f"補完後の'dri_score'の欠損値数: {missing_after}")
# Out:
# 補完後の'dri_score'の欠損値数: 0

# %%
#df_trainのデータの欠損割合の表示
missing_rate = df_train.isnull().sum() / len(df_train)
#多い順に並べ替え
missing_rate = missing_rate.sort_values(ascending=False)
missing_rate = missing_rate[missing_rate > 0]
missing_rate
# Out:
# tce_match                 0.659583
# mrd_hct                   0.576285
# cyto_score_detail         0.413993
# tce_div_match             0.395694
# tce_imm_match             0.386562
# cyto_score                0.280139
# hla_high_res_10           0.248715
# hla_high_res_8            0.202396
# hla_high_res_6            0.183472
# hla_match_dqb1_high       0.180521
# hla_low_res_10            0.175833
# conditioning_intensity    0.166285
# hla_match_c_high          0.160417
# hla_match_a_high          0.149340
# hla_nmdp_6                0.145729
# hla_match_dqb1_low        0.145625
# hla_match_b_high          0.141944
# hla_low_res_8             0.126840
# hla_match_drb1_high       0.116389
# hla_low_res_6             0.113542
# hla_match_c_low           0.097222
# hla_match_drb1_low        0.091771
# hla_match_b_low           0.089063
# cardiac                   0.088264
# peptic_ulcer              0.083993
# hla_match_a_low           0.082986
# arrhythmia                0.076458
# rheum_issue               0.075799
# rituximab                 0.074583
# pulm_severe               0.074132
# diabetes                  0.073576
# psych_disturb             0.071597
# pulm_moderate             0.071076
# hepatic_mild              0.066562
# renal_issue               0.066493
# hepatic_severe            0.064965
# donor_age                 0.062778
# obesity                   0.061111
# prior_tumor               0.058264
# melphalan_dose            0.048785
# karnofsky_score           0.030208
# cmv_status                0.022014
# ethnicity                 0.020382
# comorbidity_score         0.016563
# sex_match                 0.009062
# vent_hist                 0.008993
# in_vivo_tcd               0.007812
# gvhd_proph                0.007812
# donor_related             0.005486
# dtype: float64

# %%
import lifelines
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from lifelines import KaplanMeierFitter
from sklearn.metrics import mean_squared_error
import warnings

# %%
# 生存確率を計算する関数
# efs：無イベント生存率
# efs_time：無イベント生存までの時間
def transform_survival_probability(df, time_col='efs_time', event_col='efs'):
    kmf = KaplanMeierFitter() # インスタンスを作成
    kmf.fit(df[time_col], event_observed=df[event_col]) # カプラン・マイヤー推定量にデータをフィット
    survival_probabilities = kmf.survival_function_at_times(df[time_col]).values.flatten()
    censored_mask = df[event_col] == 0
    return survival_probabilities

# %%
# 生存確率を目的変数として代入
df_train["target"] = transform_survival_probability(df_train, time_col='efs_time', event_col='efs')
df_train.head(  )
# Out:
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No           NaN       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No           NaN       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6  ... donor_related      melphalan_dose hla_low_res_8 cardiac  \
# 0            6.0  ...     Unrelated  N/A, Mel not given           8.0      No
# 1            6.0  ...       Related  N/A, Mel not given           8.0      No
# 2            6.0  ...       Related  N/A, Mel not given           8.0      No
# 3            6.0  ...     Unrelated  N/A, Mel not given           8.0      No
# 4            6.0  ...       Related                 MEL           8.0      No
#
#   hla_match_drb1_high  pulm_moderate hla_low_res_10  efs  efs_time    target
# 0                 2.0             No           10.0  0.0    42.356  0.458687
# 1                 2.0            Yes           10.0  1.0     4.672  0.847759
# 2                 2.0             No           10.0  0.0    19.793  0.462424
# 3                 2.0             No           10.0  0.0   102.349  0.456661
# 4                 2.0             No           10.0  0.0    16.223  0.464674
#
# [5 rows x 61 columns]

# %%
# 不要になったカラム[ID,efs,efs_time]を削除
drop_cols = ["ID", 'efs', 'efs_time']

# drop_colsに含まれるカラムを削除
df_train = df_train.drop(columns=[col for col in drop_cols if col in df_train.columns])
df_train.head()
# Out:
#                         dri_score psych_disturb    cyto_score diabetes  \
# 0  N/A - non-malignant indication            No           NaN       No
# 1                    Intermediate            No  Intermediate       No
# 2  N/A - non-malignant indication            No           NaN       No
# 3                            High            No  Intermediate       No
# 4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6        graft_type  ... hepatic_mild          tce_div_match  \
# 0            6.0       Bone marrow  ...           No                    NaN
# 1            6.0  Peripheral blood  ...           No  Permissive mismatched
# 2            6.0       Bone marrow  ...           No  Permissive mismatched
# 3            6.0       Bone marrow  ...          Yes  Permissive mismatched
# 4            6.0  Peripheral blood  ...           No  Permissive mismatched
#
#   donor_related      melphalan_dose  hla_low_res_8 cardiac  \
# 0     Unrelated  N/A, Mel not given            8.0      No
# 1       Related  N/A, Mel not given            8.0      No
# 2       Related  N/A, Mel not given            8.0      No
# 3     Unrelated  N/A, Mel not given            8.0      No
# 4       Related                 MEL            8.0      No
#
#    hla_match_drb1_high  pulm_moderate hla_low_res_10    target
# 0                  2.0             No           10.0  0.458687
# 1                  2.0            Yes           10.0  0.847759
# 2                  2.0             No           10.0  0.462424
# 3                  2.0             No           10.0  0.456661
# 4                  2.0             No           10.0  0.464674
#
# [5 rows x 58 columns]

# %% [markdown]
# 欠損値を埋める基準として以下のものを考える。
#
# ・欠損割合が0.5を超えるものは削除
# ・欠損割合が0.1を下回るものは最頻値で補完（全体に対する影響が小さいと判断）
# ・欠損割合が上記の間に入っていて、かつデータ型がintかfloatのものは、特徴量間で相関係数を計算する。
# その相関係数が0.8以上くらいで高ければ、単回帰分析をして、それぞれ欠損値を補完
# ・上記のいずれにも入らないものは別途考える。(knnで補完してみたかったが、エラーになってしまったので、大体最頻値になってしまった)

# %%
#欠損の割合が0.5以上の列を削除
df_train = df_train.dropna(thresh=len(df_train)*0.5, axis=1)

# %%
#欠損の割合が0.10以下の列を抽出
low_missing_rate = missing_rate[missing_rate < 0.10]
low_missing_rate
# Out:
# hla_match_c_low       0.097222
# hla_match_drb1_low    0.091771
# hla_match_b_low       0.089063
# cardiac               0.088264
# peptic_ulcer          0.083993
# hla_match_a_low       0.082986
# arrhythmia            0.076458
# rheum_issue           0.075799
# rituximab             0.074583
# pulm_severe           0.074132
# diabetes              0.073576
# psych_disturb         0.071597
# pulm_moderate         0.071076
# hepatic_mild          0.066562
# renal_issue           0.066493
# hepatic_severe        0.064965
# donor_age             0.062778
# obesity               0.061111
# prior_tumor           0.058264
# melphalan_dose        0.048785
# karnofsky_score       0.030208
# cmv_status            0.022014
# ethnicity             0.020382
# comorbidity_score     0.016563
# sex_match             0.009062
# vent_hist             0.008993
# in_vivo_tcd           0.007812
# gvhd_proph            0.007812
# donor_related         0.005486
# dtype: float64

# %%
#low_missing_rateの列は最頻値で補完
for column in low_missing_rate.index:
    mode = df_train[column].mode()[0]
    df_train[column] = df_train[column].fillna(mode)

# %%
#更新したdf_trainの欠損率の確認
missing_rate = df_train.isnull().sum() / len(df_train)

#欠損率が0.5以上のもの、0.1以下のものがないことを確認
missing_rate_2 = missing_rate[missing_rate > 0]
missing_rate_2 = missing_rate_2.sort_values(ascending=False)
missing_rate_2
# Out:
# cyto_score_detail         0.413993
# tce_div_match             0.395694
# tce_imm_match             0.386562
# cyto_score                0.280139
# hla_high_res_10           0.248715
# hla_high_res_8            0.202396
# hla_high_res_6            0.183472
# hla_match_dqb1_high       0.180521
# hla_low_res_10            0.175833
# conditioning_intensity    0.166285
# hla_match_c_high          0.160417
# hla_match_a_high          0.149340
# hla_nmdp_6                0.145729
# hla_match_dqb1_low        0.145625
# hla_match_b_high          0.141944
# hla_low_res_8             0.126840
# hla_match_drb1_high       0.116389
# hla_low_res_6             0.113542
# dtype: float64

# %%
# df_trainからmissing_rateの列を抽出
missing_rate_columns = missing_rate_2.index

# missing_rate_columnsの列のうち、df_trainから同じ列名の列を抽出
df_missing_rate = df_train[missing_rate_columns]

df_missing_rate
# Out:
#       cyto_score_detail                  tce_div_match tce_imm_match  \
# 0                   NaN                            NaN           NaN
# 1          Intermediate          Permissive mismatched           P/P
# 2                   NaN          Permissive mismatched           P/P
# 3          Intermediate          Permissive mismatched           P/P
# 4                   NaN          Permissive mismatched           NaN
# ...                 ...                            ...           ...
# 28795      Intermediate  Bi-directional non-permissive           P/P
# 28796               TBD             GvH non-permissive           G/G
# 28797              Poor             GvH non-permissive           G/G
# 28798               NaN          Permissive mismatched           P/P
# 28799               NaN          Permissive mismatched           P/P
#
#          cyto_score  hla_high_res_10  hla_high_res_8  hla_high_res_6  \
# 0               NaN              NaN             NaN             6.0
# 1      Intermediate             10.0             8.0             6.0
# 2               NaN             10.0             8.0             6.0
# 3      Intermediate             10.0             8.0             6.0
# 4               NaN             10.0             8.0             6.0
# ...             ...              ...             ...             ...
# 28795     Favorable             10.0             8.0             6.0
# 28796          Poor              6.0             4.0             3.0
# 28797          Poor             10.0             8.0             6.0
# 28798          Poor              5.0             4.0             3.0
# 28799           NaN             10.0             8.0             6.0
#
#        hla_match_dqb1_high  hla_low_res_10 conditioning_intensity  \
# 0                      2.0            10.0                    NaN
# 1                      2.0            10.0                    MAC
# 2                      2.0            10.0                    NaN
# 3                      2.0            10.0                    MAC
# 4                      2.0            10.0                    MAC
# ...                    ...             ...                    ...
# 28795                  2.0            10.0                    MAC
# 28796                  2.0             8.0                    RIC
# 28797                  2.0            10.0                    MAC
# 28798                  1.0             5.0                    NMA
# 28799                  2.0            10.0                    NaN
#
#        hla_match_c_high  hla_match_a_high  hla_nmdp_6  hla_match_dqb1_low  \
# 0                   NaN               2.0         6.0                 2.0
# 1                   2.0               2.0         6.0                 2.0
# 2                   2.0               2.0         6.0                 2.0
# 3                   2.0               2.0         6.0                 2.0
# 4                   2.0               2.0         5.0                 2.0
# ...                 ...               ...         ...                 ...
# 28795               2.0               2.0         6.0                 2.0
# 28796               1.0               1.0         4.0                 2.0
# 28797               2.0               2.0         6.0                 2.0
# 28798               1.0               1.0         3.0                 1.0
# 28799               2.0               2.0         6.0                 2.0
#
#        hla_match_b_high  hla_low_res_8  hla_match_drb1_high  hla_low_res_6
# 0                   2.0            8.0                  2.0            6.0
# 1                   2.0            8.0                  2.0            6.0
# 2                   2.0            8.0                  2.0            6.0
# 3                   2.0            8.0                  2.0            6.0
# 4                   2.0            8.0                  2.0            6.0
# ...                 ...            ...                  ...            ...
# 28795               2.0            8.0                  2.0            6.0
# 28796               1.0            6.0                  1.0            5.0
# 28797               2.0            8.0                  2.0            6.0
# 28798               1.0            4.0                  1.0            3.0
# 28799               2.0            8.0                  2.0            6.0
#
# [28800 rows x 18 columns]

# %%
# 数値型の列のみを選択
numeric_df_train = df_missing_rate.select_dtypes(include=[np.number])

numeric_df_train
# Out:
#        hla_high_res_10  hla_high_res_8  hla_high_res_6  hla_match_dqb1_high  \
# 0                  NaN             NaN             6.0                  2.0
# 1                 10.0             8.0             6.0                  2.0
# 2                 10.0             8.0             6.0                  2.0
# 3                 10.0             8.0             6.0                  2.0
# 4                 10.0             8.0             6.0                  2.0
# ...                ...             ...             ...                  ...
# 28795             10.0             8.0             6.0                  2.0
# 28796              6.0             4.0             3.0                  2.0
# 28797             10.0             8.0             6.0                  2.0
# 28798              5.0             4.0             3.0                  1.0
# 28799             10.0             8.0             6.0                  2.0
#
#        hla_low_res_10  hla_match_c_high  hla_match_a_high  hla_nmdp_6  \
# 0                10.0               NaN               2.0         6.0
# 1                10.0               2.0               2.0         6.0
# 2                10.0               2.0               2.0         6.0
# 3                10.0               2.0               2.0         6.0
# 4                10.0               2.0               2.0         5.0
# ...               ...               ...               ...         ...
# 28795            10.0               2.0               2.0         6.0
# 28796             8.0               1.0               1.0         4.0
# 28797            10.0               2.0               2.0         6.0
# 28798             5.0               1.0               1.0         3.0
# 28799            10.0               2.0               2.0         6.0
#
#        hla_match_dqb1_low  hla_match_b_high  hla_low_res_8  \
# 0                     2.0               2.0            8.0
# 1                     2.0               2.0            8.0
# 2                     2.0               2.0            8.0
# 3                     2.0               2.0            8.0
# 4                     2.0               2.0            8.0
# ...                   ...               ...            ...
# 28795                 2.0               2.0            8.0
# 28796                 2.0               1.0            6.0
# 28797                 2.0               2.0            8.0
# 28798                 1.0               1.0            4.0
# 28799                 2.0               2.0            8.0
#
#        hla_match_drb1_high  hla_low_res_6
# 0                      2.0            6.0
# 1                      2.0            6.0
# 2                      2.0            6.0
# 3                      2.0            6.0
# 4                      2.0            6.0
# ...                    ...            ...
# 28795                  2.0            6.0
# 28796                  1.0            5.0
# 28797                  2.0            6.0
# 28798                  1.0            3.0
# 28799                  2.0            6.0
#
# [28800 rows x 13 columns]

# %%
# 変数間の相関係数を計算
correlation = numeric_df_train.corr()
#変数の相関係数が0.8以上の組み合わせを抽出
high_correlation = correlation[correlation > 0.8]
#high_correlationの組み合わせを表示
high_correlation
# Out:
#                      hla_high_res_10  hla_high_res_8  hla_high_res_6  \
# hla_high_res_10             1.000000        0.986125        0.968703
# hla_high_res_8              0.986125        1.000000        0.983351
# hla_high_res_6              0.968703        0.983351        1.000000
# hla_match_dqb1_high         0.808341             NaN             NaN
# hla_low_res_10              0.929522        0.922255        0.902408
# hla_match_c_high            0.853098        0.858282             NaN
# hla_match_a_high            0.804656        0.822836        0.854499
# hla_nmdp_6                  0.886625        0.883250        0.870521
# hla_match_dqb1_low               NaN             NaN             NaN
# hla_match_b_high            0.872777        0.883800        0.884266
# hla_low_res_8               0.926091        0.922293        0.903878
# hla_match_drb1_high         0.879950        0.879812        0.886769
# hla_low_res_6               0.912479        0.909537        0.899229
#
#                      hla_match_dqb1_high  hla_low_res_10  hla_match_c_high  \
# hla_high_res_10                 0.808341        0.929522          0.853098
# hla_high_res_8                       NaN        0.922255          0.858282
# hla_high_res_6                       NaN        0.902408               NaN
# hla_match_dqb1_high             1.000000             NaN               NaN
# hla_low_res_10                       NaN        1.000000               NaN
# hla_match_c_high                     NaN             NaN          1.000000
# hla_match_a_high                     NaN             NaN               NaN
# hla_nmdp_6                           NaN        0.890334               NaN
# hla_match_dqb1_low                   NaN             NaN               NaN
# hla_match_b_high                     NaN             NaN               NaN
# hla_low_res_8                        NaN        0.985430               NaN
# hla_match_drb1_high                  NaN        0.821292               NaN
# hla_low_res_6                        NaN        0.968904               NaN
#
#                      hla_match_a_high  hla_nmdp_6  hla_match_dqb1_low  \
# hla_high_res_10              0.804656    0.886625                 NaN
# hla_high_res_8               0.822836    0.883250                 NaN
# hla_high_res_6               0.854499    0.870521                 NaN
# hla_match_dqb1_high               NaN         NaN                 NaN
# hla_low_res_10                    NaN    0.890334                 NaN
# hla_match_c_high                  NaN         NaN                 NaN
# hla_match_a_high             1.000000         NaN                 NaN
# hla_nmdp_6                        NaN    1.000000                 NaN
# hla_match_dqb1_low                NaN         NaN                 1.0
# hla_match_b_high                  NaN         NaN                 NaN
# hla_low_res_8                     NaN    0.889669                 NaN
# hla_match_drb1_high               NaN         NaN                 NaN
# hla_low_res_6                     NaN    0.882176                 NaN
#
#                      hla_match_b_high  hla_low_res_8  hla_match_drb1_high  \
# hla_high_res_10              0.872777       0.926091             0.879950
# hla_high_res_8               0.883800       0.922293             0.879812
# hla_high_res_6               0.884266       0.903878             0.886769
# hla_match_dqb1_high               NaN            NaN                  NaN
# hla_low_res_10                    NaN       0.985430             0.821292
# hla_match_c_high                  NaN            NaN                  NaN
# hla_match_a_high                  NaN            NaN                  NaN
# hla_nmdp_6                        NaN       0.889669                  NaN
# hla_match_dqb1_low                NaN            NaN                  NaN
# hla_match_b_high             1.000000            NaN                  NaN
# hla_low_res_8                     NaN       1.000000             0.813066
# hla_match_drb1_high               NaN       0.813066             1.000000
# hla_low_res_6                     NaN       0.983812             0.806428
#
#                      hla_low_res_6
# hla_high_res_10           0.912479
# hla_high_res_8            0.909537
# hla_high_res_6            0.899229
# hla_match_dqb1_high            NaN
# hla_low_res_10            0.968904
# hla_match_c_high               NaN
# hla_match_a_high               NaN
# hla_nmdp_6                0.882176
# hla_match_dqb1_low             NaN
# hla_match_b_high               NaN
# hla_low_res_8             0.983812
# hla_match_drb1_high       0.806428
# hla_low_res_6             1.000000

# %%
for column in high_correlation.columns:
    # 自分自身を除いた相関を取得
    other_corr = high_correlation[column].drop(column)
    max_corr = other_corr.max()
    most_correlated_feature = other_corr.idxmax()  # 最大相関の特徴量を取得
    print(f"{column}と相関が最も高い特徴量: {most_correlated_feature} (相関係数: {max_corr})")
# Out:
# hla_high_res_10と相関が最も高い特徴量: hla_high_res_8 (相関係数: 0.9861252716917301)
# hla_high_res_8と相関が最も高い特徴量: hla_high_res_10 (相関係数: 0.9861252716917301)
# hla_high_res_6と相関が最も高い特徴量: hla_high_res_8 (相関係数: 0.9833507797663403)
# hla_match_dqb1_highと相関が最も高い特徴量: hla_high_res_10 (相関係数: 0.8083406740540625)
# hla_low_res_10と相関が最も高い特徴量: hla_low_res_8 (相関係数: 0.9854304122808194)
# hla_match_c_highと相関が最も高い特徴量: hla_high_res_8 (相関係数: 0.8582820487584473)
# hla_match_a_highと相関が最も高い特徴量: hla_high_res_6 (相関係数: 0.8544986780482423)
# hla_nmdp_6と相関が最も高い特徴量: hla_low_res_10 (相関係数: 0.8903341252416828)
# hla_match_dqb1_lowと相関が最も高い特徴量: nan (相関係数: nan)
# hla_match_b_highと相関が最も高い特徴量: hla_high_res_6 (相関係数: 0.8842655963868669)
# hla_low_res_8と相関が最も高い特徴量: hla_low_res_10 (相関係数: 0.9854304122808194)
# hla_match_drb1_highと相関が最も高い特徴量: hla_high_res_6 (相関係数: 0.8867687385181369)
# hla_low_res_6と相関が最も高い特徴量: hla_low_res_8 (相関係数: 0.9838123742279061)
# C:\Users\eikik\AppData\Local\Temp\ipykernel_20548\1400108618.py:5: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   most_correlated_feature = other_corr.idxmax()  # 最大相関の特徴量を取得

# %%
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# 先に high_correlation の結果を利用して、各特徴量に対して相方を決定
most_correlated = {}
for column in high_correlation.columns:
    other_corr = high_correlation[column].drop(column).dropna()  # 自分自身を除外し NaN を除く
    if other_corr.empty:
        print(f"{column}: 他の特徴量との相関係数が有効な値ではありません（すべて NaN）。スキップします。")
        continue
    most_correlated_feature = other_corr.idxmax()  # 最大相関の特徴量
    most_correlated[column] = most_correlated_feature

# 欠損値の補完処理
for target_column, related_column in most_correlated.items():
    print(f"補完処理: {target_column} を {related_column} を使って補完中")

    # 欠損値がない行をモデルの訓練データとする
    train_data = df_train.dropna(subset=[target_column, related_column])

    # 欠損値がある行を予測対象データとする
    missing_data = df_train[df_train[target_column].isnull()]

    if missing_data.empty:
        print(f"{target_column} に欠損値はありません。スキップします。")
        continue

    # モデルの訓練
    X_train = train_data[[related_column]]
    y_train = train_data[target_column]

    # 欠損値を補完するためのインプーターを作成
    imputer = SimpleImputer(strategy='mean')
    X_train_imputed = imputer.fit_transform(X_train)

    model = LinearRegression()
    model.fit(X_train_imputed, y_train)

    # 欠損値の補完
    X_missing = missing_data[[related_column]]
    X_missing_imputed = imputer.transform(X_missing)
    predicted_values = model.predict(X_missing_imputed)

    # 補完結果をデータに反映
    df_train.loc[missing_data.index, target_column] = predicted_values

# 結果の確認
print("補完後の欠損値数:")
print(df_train.isnull().sum())
# Out:
# hla_match_dqb1_low: 他の特徴量との相関係数が有効な値ではありません（すべて NaN）。スキップします。
# 補完処理: hla_high_res_10 を hla_high_res_8 を使って補完中
# 補完処理: hla_high_res_8 を hla_high_res_10 を使って補完中
# 補完処理: hla_high_res_6 を hla_high_res_8 を使って補完中
# 補完処理: hla_match_dqb1_high を hla_high_res_10 を使って補完中
# 補完処理: hla_low_res_10 を hla_low_res_8 を使って補完中
# 補完処理: hla_match_c_high を hla_high_res_8 を使って補完中
# 補完処理: hla_match_a_high を hla_high_res_6 を使って補完中
# 補完処理: hla_nmdp_6 を hla_low_res_10 を使って補完中
# 補完処理: hla_match_b_high を hla_high_res_6 を使って補完中
# 補完処理: hla_low_res_8 を hla_low_res_10 を使って補完中
# 補完処理: hla_match_drb1_high を hla_high_res_6 を使って補完中
# 補完処理: hla_low_res_6 を hla_low_res_8 を使って補完中
# 補完後の欠損値数:
# dri_score                     0
# psych_disturb                 0
# cyto_score                 8068
# diabetes                      0
# hla_match_c_high              0
# hla_high_res_8                0
# tbi_status                    0
# arrhythmia                    0
# hla_low_res_6                 0
# graft_type                    0
# vent_hist                     0
# renal_issue                   0
# pulm_severe                   0
# prim_disease_hct              0
# hla_high_res_6                0
# cmv_status                    0
# hla_high_res_10               0
# hla_match_dqb1_high           0
# tce_imm_match             11133
# hla_nmdp_6                    0
# hla_match_c_low               0
# rituximab                     0
# hla_match_drb1_low            0
# hla_match_dqb1_low         4194
# prod_type                     0
# cyto_score_detail         11923
# conditioning_intensity     4789
# ethnicity                     0
# year_hct                      0
# obesity                       0
# in_vivo_tcd                   0
# hla_match_a_high              0
# hepatic_severe                0
# donor_age                     0
# prior_tumor                   0
# hla_match_b_low               0
# peptic_ulcer                  0
# age_at_hct                    0
# hla_match_a_low               0
# gvhd_proph                    0
# rheum_issue                   0
# sex_match                     0
# hla_match_b_high              0
# race_group                    0
# comorbidity_score             0
# karnofsky_score               0
# hepatic_mild                  0
# tce_div_match             11396
# donor_related                 0
# melphalan_dose                0
# hla_low_res_8                 0
# cardiac                       0
# hla_match_drb1_high           0
# pulm_moderate                 0
# hla_low_res_10                0
# target                        0
# dtype: int64

# %%
#hla_match_dqb1_lowの統計量の表示
df_train['hla_match_dqb1_low'].describe()
# Out:
# count    24606.000000
# mean         1.773795
# std          0.427130
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: hla_match_dqb1_low, dtype: float64

# %%
#hla_match_dqb1_lowを最頻値で補完
mode = df_train['hla_match_dqb1_low'].mode()[0]
df_train['hla_match_dqb1_low'] = df_train['hla_match_dqb1_low'].fillna(mode)

# %%
#df_trainの欠損割合の表示
missing_rate_3 = df_train.isnull().sum() / len(df_train)
#多い順に並べ替え
missing_rate_3 = missing_rate_3.sort_values(ascending=False)
missing_rate_3= missing_rate_3[missing_rate_3 > 0]
missing_rate_3
# Out:
# cyto_score_detail         0.413993
# tce_div_match             0.395694
# tce_imm_match             0.386562
# cyto_score                0.280139
# conditioning_intensity    0.166285
# dtype: float64

# %%
#missing_rate_3の列を表示
missing_rate_columns_3 = missing_rate_3.index
df_missing_rate_3 = df_train[missing_rate_columns_3]
df_missing_rate_3
# Out:
#       cyto_score_detail                  tce_div_match tce_imm_match  \
# 0                   NaN                            NaN           NaN
# 1          Intermediate          Permissive mismatched           P/P
# 2                   NaN          Permissive mismatched           P/P
# 3          Intermediate          Permissive mismatched           P/P
# 4                   NaN          Permissive mismatched           NaN
# ...                 ...                            ...           ...
# 28795      Intermediate  Bi-directional non-permissive           P/P
# 28796               TBD             GvH non-permissive           G/G
# 28797              Poor             GvH non-permissive           G/G
# 28798               NaN          Permissive mismatched           P/P
# 28799               NaN          Permissive mismatched           P/P
#
#          cyto_score conditioning_intensity
# 0               NaN                    NaN
# 1      Intermediate                    MAC
# 2               NaN                    NaN
# 3      Intermediate                    MAC
# 4               NaN                    MAC
# ...             ...                    ...
# 28795     Favorable                    MAC
# 28796          Poor                    RIC
# 28797          Poor                    MAC
# 28798          Poor                    NMA
# 28799           NaN                    NaN
#
# [28800 rows x 5 columns]

# %%
#cyto_score_detailの統計量の表示
df_train['cyto_score_detail'].describe()
#要素ごとの個数を表示
df_train['cyto_score_detail'].value_counts()
# Out:
# cyto_score_detail
# Intermediate    11158
# Poor             3323
# Favorable        1208
# TBD              1043
# Not tested        145
# Name: count, dtype: int64

# %%
#cyto_score_detailを最頻値で補完
mode = df_train['cyto_score_detail'].mode()[0]
df_train['cyto_score_detail'] = df_train['cyto_score_detail'].fillna(mode)

# %%
#tce_div_matchの統計量の表示
df_train['tce_div_match'].describe()
#要素ごとの個数を表示
df_train['tce_div_match'].value_counts()
# Out:
# tce_div_match
# Permissive mismatched            12936
# GvH non-permissive                2458
# HvG non-permissive                1417
# Bi-directional non-permissive      593
# Name: count, dtype: int64

# %%
#tce_div_matchを最頻値で補完
mode = df_train['tce_div_match'].mode()[0]
df_train['tce_div_match'] = df_train['tce_div_match'].fillna(mode)

# %%
#tce_imm_matchの統計量の表示
df_train['tce_imm_match'].describe()
#要素ごとの個数を表示
df_train['tce_imm_match'].value_counts()
# Out:
# tce_imm_match
# P/P    13114
# G/G     2522
# H/H     1084
# G/B      544
# H/B      229
# P/H       83
# P/B       66
# P/G       25
# Name: count, dtype: int64

# %%
#tce_imm_matchを最頻値で補完
mode = df_train['tce_imm_match'].mode()[0]
df_train['tce_imm_match'] = df_train['tce_imm_match'].fillna(mode)

# %%
#cyto_scoreの統計量の表示
df_train['cyto_score'].describe()
#要素ごとの個数を表示
df_train['cyto_score'].value_counts()
# Out:
# cyto_score
# Poor            8802
# Intermediate    6376
# Favorable       3011
# TBD             1341
# Normal           643
# Other            504
# Not tested        55
# Name: count, dtype: int64

# %%
#cyto_scoreを度数を元に作成した確率を用いて補完
prob = df_train['cyto_score'].value_counts(normalize=True)
df_train['cyto_score'] = df_train['cyto_score'].fillna(np.random.choice(prob.index, p=prob.values))

# %%
#conditioning_intensityの統計量の表示
df_train['conditioning_intensity'].describe()
#要素ごとの個数を表示
df_train['conditioning_intensity'].value_counts()
# Out:
# conditioning_intensity
# MAC                              12288
# RIC                               7722
# NMA                               3479
# TBD                                373
# No drugs reported                   87
# N/A, F(pre-TED) not submitted       62
# Name: count, dtype: int64

# %% [markdown]
# データのばらつきが大きい。。最頻値で補完は良くなさそう？
# かといって何が良いのかわからないけど一旦

# %%
#conditioning_intensityを度数を元に作成した確率を用いて補完
prob = df_train['conditioning_intensity'].value_counts(normalize=True)
df_train['conditioning_intensity'] = df_train['conditioning_intensity'].fillna(np.random.choice(prob.index, p=prob.values))

# %%
#train.csvのobject型の列を抽出
object_columns = df_train.select_dtypes(include=object)
object_columns
# Out:
#                                                dri_score psych_disturb  \
# 0                         N/A - non-malignant indication            No
# 1                                           Intermediate            No
# 2                         N/A - non-malignant indication            No
# 3                                                   High            No
# 4                                                   High            No
# ...                                                  ...           ...
# 28795  Intermediate - TED AML case <missing cytogenetics            No
# 28796                                               High            No
# 28797                                   TBD cytogenetics            No
# 28798                     N/A - non-malignant indication            No
# 28799                                    N/A - pediatric            No
#
#          cyto_score diabetes          tbi_status arrhythmia        graft_type  \
# 0              Poor       No              No TBI         No       Bone marrow
# 1      Intermediate       No  TBI +- Other, >cGy         No  Peripheral blood
# 2              Poor       No              No TBI         No       Bone marrow
# 3      Intermediate       No              No TBI         No       Bone marrow
# 4              Poor       No              No TBI         No  Peripheral blood
# ...             ...      ...                 ...        ...               ...
# 28795     Favorable       No              No TBI         No  Peripheral blood
# 28796          Poor      Yes              No TBI         No  Peripheral blood
# 28797          Poor       No              No TBI         No  Peripheral blood
# 28798          Poor       No              No TBI         No  Peripheral blood
# 28799          Poor       No              No TBI         No       Bone marrow
#
#       vent_hist renal_issue pulm_severe  ...                  gvhd_proph  \
# 0            No          No          No  ...                     FKalone
# 1            No          No          No  ...      Other GVHD Prophylaxis
# 2            No          No          No  ...      Cyclophosphamide alone
# 3            No          No          No  ...           FK+ MMF +- others
# 4            No          No          No  ...         TDEPLETION +- other
# ...         ...         ...         ...  ...                         ...
# 28795        No          No          No  ...  FK+ MTX +- others(not MMF)
# 28796        No          No          No  ...  Cyclophosphamide +- others
# 28797        No          No          No  ...           FK+ MMF +- others
# 28798        No          No          No  ...      Cyclophosphamide alone
# 28799        No          No          No  ...  Cyclophosphamide +- others
#
#       rheum_issue sex_match                                 race_group  \
# 0              No       M-F                         More than one race
# 1              No       F-F                                      Asian
# 2              No       F-M                         More than one race
# 3              No       M-M                                      White
# 4              No       M-F           American Indian or Alaska Native
# ...           ...       ...                                        ...
# 28795          No       M-F                         More than one race
# 28796          No       M-F  Native Hawaiian or other Pacific Islander
# 28797          No       M-F  Native Hawaiian or other Pacific Islander
# 28798          No       M-M                  Black or African-American
# 28799          No       M-M                  Black or African-American
#
#       hepatic_mild                  tce_div_match donor_related  \
# 0               No          Permissive mismatched     Unrelated
# 1               No          Permissive mismatched       Related
# 2               No          Permissive mismatched       Related
# 3              Yes          Permissive mismatched     Unrelated
# 4               No          Permissive mismatched       Related
# ...            ...                            ...           ...
# 28795           No  Bi-directional non-permissive       Related
# 28796           No             GvH non-permissive       Related
# 28797           No             GvH non-permissive     Unrelated
# 28798           No          Permissive mismatched       Related
# 28799           No          Permissive mismatched       Related
#
#            melphalan_dose cardiac pulm_moderate
# 0      N/A, Mel not given      No            No
# 1      N/A, Mel not given      No           Yes
# 2      N/A, Mel not given      No            No
# 3      N/A, Mel not given      No            No
# 4                     MEL      No            No
# ...                   ...     ...           ...
# 28795  N/A, Mel not given      No            No
# 28796  N/A, Mel not given     Yes           Yes
# 28797  N/A, Mel not given      No            No
# 28798                 MEL      No            No
# 28799                 MEL      No           Yes
#
# [28800 rows x 33 columns]

# %%
# ojbect型をcategory型に変換
def convert_object_to_category(df):
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].astype('category')
    return df

df_train = convert_object_to_category(df_train)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28800 entries, 0 to 28799
# Data columns (total 56 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   dri_score               28800 non-null  category
#  1   psych_disturb           28800 non-null  category
#  2   cyto_score              28800 non-null  category
#  3   diabetes                28800 non-null  category
#  4   hla_match_c_high        28800 non-null  float64
#  5   hla_high_res_8          28800 non-null  float64
#  6   tbi_status              28800 non-null  category
#  7   arrhythmia              28800 non-null  category
#  8   hla_low_res_6           28800 non-null  float64
#  9   graft_type              28800 non-null  category
#  10  vent_hist               28800 non-null  category
#  11  renal_issue             28800 non-null  category
#  12  pulm_severe             28800 non-null  category
#  13  prim_disease_hct        28800 non-null  category
#  14  hla_high_res_6          28800 non-null  float64
#  15  cmv_status              28800 non-null  category
#  16  hla_high_res_10         28800 non-null  float64
#  17  hla_match_dqb1_high     28800 non-null  float64
#  18  tce_imm_match           28800 non-null  category
#  19  hla_nmdp_6              28800 non-null  float64
#  20  hla_match_c_low         28800 non-null  float64
#  21  rituximab               28800 non-null  category
#  22  hla_match_drb1_low      28800 non-null  float64
#  23  hla_match_dqb1_low      28800 non-null  float64
#  24  prod_type               28800 non-null  category
#  25  cyto_score_detail       28800 non-null  category
#  26  conditioning_intensity  28800 non-null  category
#  27  ethnicity               28800 non-null  category
#  28  year_hct                28800 non-null  int64
#  29  obesity                 28800 non-null  category
#  30  in_vivo_tcd             28800 non-null  category
#  31  hla_match_a_high        28800 non-null  float64
#  32  hepatic_severe          28800 non-null  category
#  33  donor_age               28800 non-null  float64
#  34  prior_tumor             28800 non-null  category
#  35  hla_match_b_low         28800 non-null  float64
#  36  peptic_ulcer            28800 non-null  category
#  37  age_at_hct              28800 non-null  float64
#  38  hla_match_a_low         28800 non-null  float64
#  39  gvhd_proph              28800 non-null  category
#  40  rheum_issue             28800 non-null  category
#  41  sex_match               28800 non-null  category
#  42  hla_match_b_high        28800 non-null  float64
#  43  race_group              28800 non-null  category
#  44  comorbidity_score       28800 non-null  float64
#  45  karnofsky_score         28800 non-null  float64
#  46  hepatic_mild            28800 non-null  category
#  47  tce_div_match           28800 non-null  category
#  48  donor_related           28800 non-null  category
#  49  melphalan_dose          28800 non-null  category
#  50  hla_low_res_8           28800 non-null  float64
#  51  cardiac                 28800 non-null  category
#  52  hla_match_drb1_high     28800 non-null  float64
#  53  pulm_moderate           28800 non-null  category
#  54  hla_low_res_10          28800 non-null  float64
#  55  target                  28800 non-null  float64
# dtypes: category(33), float64(22), int64(1)
# memory usage: 6.0 MB

# %%
#データの欠損の確認
missing_rate_4 = df_train.isnull().sum() / len(df_train)
missing_rate_4 = missing_rate_4.sort_values(ascending=False)
missing_rate_4 = missing_rate_4[missing_rate_4 > 0]
missing_rate_4
# Out:
# Series([], dtype: float64)

# %% [markdown]
# よくわかんないけど、とりあえず欠損値はなくなった！

# %%
from sklearn.preprocessing import StandardScaler

# 数値列だけを抽出
numeric_columns = df_train.select_dtypes(include=['float64', 'int64']).columns
numeric_data = df_train[numeric_columns]

# 正規化 (StandardScalerを使用)
scaler = StandardScaler()
normalized_numeric_data = scaler.fit_transform(numeric_data)

# 正規化されたデータをデータフレームに変換
normalized_numeric_df = pd.DataFrame(normalized_numeric_data, columns=numeric_columns, index=df_train.index)

# 元のカテゴリ変数と結合
df_train_normalized = pd.concat([df_train.drop(columns=numeric_columns), normalized_numeric_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.preprocessing import StandardScaler
#       3 # 数値列だけを抽出
# ----> 4 numeric_columns = df_train.select_dtypes(include=['float64', 'int64']).columns
#       5 numeric_data = df_train[numeric_columns]
#       7 # 正規化 (StandardScalerを使用)
#
# NameError: name 'df_train' is not defined

# %%
#欠損値がなくなり、正規化を行ったdf_trainのデータをCSVファイルに保存
df_train_preprocessed = pd.DataFrame(df_train_normalized, columns=df_train.columns)
df_train_preprocessed.to_csv(r"C:\Users\eikik\python\python_dat\equity-post-HCT-survival-predictions\train_preprocessed.csv", index=False)

# %% [markdown]
# テストデータは３つしかないから一旦置いておきます。
